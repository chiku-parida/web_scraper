# %%
# !pip install requests beautifulsoup4 pandas

# %%
import requests

from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
# URL of the website to scrape
url = "https://www.imdb.com/chart/top"

# Send an HTTP GET request to the website
response = requests.get(url)

# Parse the HTML code using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Extract the relevant information from the HTML code
movies = []
for row in soup.select('tbody.lister-list tr'):
  title = row.find('td', class_='titleColumn').find('a').get_text()
  print(title)
  year = row.find('td', class_='titleColumn').find('span', class_='secondaryInfo').get_text()[1:-1]
  rating = row.find('td', class_='ratingColumn imdbRating').find('strong').get_text()
  movies.append([title, year, rating])

# Store the information in a pandas dataframe
  df = pd.DataFrame(movies, columns=['Title', 'Year', 'Rating'])

# Add a delay between requests to avoid overwhelming the website with requests
  time.sleep(1)

# %%
# Export the data to a CSV file
df.to_csv('/content/drive/MyDrive/webscrap/top-rated-movies.csv', index=False)

# %%
data = pd.read_csv('/content/drive/MyDrive/webscrap/top-rated-movies.csv')

# %%
print(movies)
# Out:
# []

# %%
from bs4 import BeautifulSoup
# Send an HTTP request to the URL of the webpage you want to access
response = requests.get("http://abulafia.mt.ic.ac.uk/shannon/radius.php")
# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")
# Extract the text content of the webpage
text = soup.get_text()
print(text)

# %%
# URL of the website to scrape
url = "http://abulafia.mt.ic.ac.uk/shannon/radius.php"

# Send an HTTP GET request to the website
response = requests.get(url)

# Parse the HTML code using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Extract the relevant information from the HTML code
data = []
for row in soup.select('tbody.lister-list tr'):
  element = row.find('td', class_='titleColumn').find('a').get_text()
  print(element)
  charge = row.find('td', class_='titleColumn').find('span', class_='secondaryInfo').get_text()[1:-1]
  coordination = row.find('td', class_='ratingColumn imdbRating').find('strong').get_text()
  crystal_radius = []
  ionic_radius = []
  data.append([element, charge, coordination, crystal_radius, ionic_radius])

# Store the information in a pandas dataframe
  df = pd.DataFrame(movies, columns=['Element', 'Charge', 'Coordination', 'Crystal Radius', 'Ionic Radius'])

# Add a delay between requests to avoid overwhelming the website with requests
  time.sleep(1)

# %%
import requests
from bs4 import BeautifulSoup

# Step 1: Send an HTTP request and get HTML content
url = "http://abulafia.mt.ic.ac.uk/shannon/radius.php"
response = requests.get(url)
html_content = response.content

# Step 2: Use BeautifulSoup to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Step 3: Locate the table element and extract data
table = soup.find('table')  # You may need to adjust this based on the actual HTML structure

if table:
    # Iterate through rows
    for row in table.find_all('tr'):
        # Iterate through columns in each row
        columns = row.find_all(['td', 'th'])
        row_data = [column.text.strip() for column in columns]

        # Process or print the data as needed
        print(row_data)
else:
    print("Table not found on the web page.")
# Out:
# ['', 'Radii for All Species']
# ['Ion', 'Charge', 'Coordination', 'Spin State', 'Crystal Radius', 'Ionic Radius', 'Key*']
# ['Ac', '3', 'VI', '', '1.26', '1.12', 'R']
# ['Ag', '1', 'II', '', '0.81', '0.67', '']
# ['IV', '', '1.14', '1', 'C']
# ['IVSQ', '', '1.16', '1.02', '']
# ['V', '', '1.23', '1.09', 'C']
# ['VI', '', '1.29', '1.15', 'C']
# ['VII', '', '1.36', '1.22', '']
# ['VIII', '', '1.42', '1.28', '']
# ['2', 'IVSQ', '', '0.93', '0.79', '']
# ['VI', '', '1.08', '0.94', '']
# ['3', 'IVSQ', '', '0.81', '0.67', '']
# ['VI', '', '0.89', '0.75', 'R']
# ['Al', '3', 'IV', '', '0.53', '0.39', '*']
# ['V', '', '0.62', '0.48', '']
# ['VI', '', '0.675', '0.535', 'R*']
# ['Am', '2', 'VII', '', '1.35', '1.21', '']
# ['VIII', '', '1.4', '1.26', '']
# ['IX', '', '1.45', '1.31', '']
# ['3', 'VI', '', '1.115', '0.975', 'R']
# ['VIII', '', '1.23', '1.09', '']
# ['4', 'VI', '', '0.99', '0.85', 'R']
# ['VIII', '', '1.09', '0.95', '']
# ['As', '3', 'VI', '', '0.72', '0.58', 'A']
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Step 1: Send an HTTP request and get HTML content
url = "http://abulafia.mt.ic.ac.uk/shannon/radius.php"
response = requests.get(url)
html_content = response.content

# Step 2: Use BeautifulSoup to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Step 3: Locate the table element and extract data based on a condition
table = soup.find('table')  # You may need to adjust this based on the actual HTML structure

if table:
    # Iterate through rows
    for row in table.find_all('tr'):
        # Iterate through columns in each row
        columns = row.find_all(['td', 'th'])
        row_data = [column.text.strip() for column in columns]

        # Check the condition (for example, extract rows where the second column has a specific value)
        if len(row_data) >= 2 and row_data[1] == 'VI':
            # Process or print the data as needed
            print(row_data)
else:
    print("Table not found on the web page.")
# Out:
# ['3', 'VI', '', '1.115', '0.975', 'R']
# ['4', 'VI', '', '0.99', '0.85', 'R']
# ['5', 'VI', '', '0.71', '0.57', '']
# ['5', 'VI', '', '0.9', '0.76', 'E']
# ['4', 'VI', '', '0.97', '0.83', 'R']
# ['4', 'VI', '', '1.01', '0.87', 'R']
# ['4', 'VI', '', '0.961', '0.821', 'R']
# ['4', 'VI', '', '0.99', '0.85', 'R']
# ['3', 'VI', 'Low Spin', '0.685', '0.545', 'R*']
# ['3', 'VI', '', '0.755', '0.615', 'R*']
# ['3', 'VI', 'Low Spin', '0.68', '0.54', '']
# ['3', 'VI', '', '1.052', '0.912', 'R']
# ['3', 'VI', '', '1.087', '0.947', 'R']
# ['7', 'VI', '', '0.22', '0.08', 'A']
# ['4', 'VI', '', '0.725', '0.585', 'R']
# ['4', 'VI', '', '0.765', '0.625', 'R']
# ['5', 'VI', '', '0.71', '0.57', 'EM']
# ['4', 'VI', '', '0.79', '0.65', 'RM']
# ['3', 'VI', '', '0.3', '0.16', 'A']
# ['4', 'VI', '', '0.82', '0.68', 'RE']
# ['3', 'VI', '', '1.123', '0.983', 'R']
# ['3', 'VI', 'Low Spin', '0.7', '0.56', 'R*']
# ['4', 'VI', 'Low Spin', '0.62', '0.48', 'R']
# ['3', 'VI', '', '1.15', '1.01', 'R']
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Step 1: Send an HTTP request and get HTML content
url = "http://abulafia.mt.ic.ac.uk/shannon/radius.php"
response = requests.get(url)
html_content = response.content

# Step 2: Use BeautifulSoup to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Step 3: Locate the table element and extract data based on a condition
table = soup.find('table')  # You may need to adjust this based on the actual HTML structure

if table:
    # Iterate through rows
    for row in table.find_all('tr'):
        # Iterate through columns in each row
        columns = row.find_all(['td', 'th'])
        row_data = [column.text.strip() for column in columns]

        # Check the condition (for example, extract rows where the second column has a specific value)
        if len(row_data) == 7 and row_data[2] == 'VI':
            # Process or print the data as needed
            print(row_data)
else:
    print("Table not found on the web page.")
# Out:
# ['Ac', '3', 'VI', '', '1.26', '1.12', 'R']
# ['As', '3', 'VI', '', '0.72', '0.58', 'A']
# ['At', '7', 'VI', '', '0.76', '0.62', 'A']
# ['Au', '1', 'VI', '', '1.51', '1.37', 'A']
# ['Ba', '2', 'VI', '', '1.49', '1.35', '']
# ['Bk', '3', 'VI', '', '1.1', '0.96', 'R']
# ['Br', '-1', 'VI', '', '1.82', '1.96', 'P']
# ['Ca', '2', 'VI', '', '1.14', '1', '']
# ['Ce', '3', 'VI', '', '1.15', '1.01', 'R']
# ['Cf', '3', 'VI', '', '1.09', '0.95', 'R']
# ['Cl', '-1', 'VI', '', '1.67', '1.81', 'P']
# ['Cm', '3', 'VI', '', '1.11', '0.97', 'R']
# ['Cr', '2', 'VI', 'High Spin', '0.94', '0.8', 'R*']
# ['Cs', '1', 'VI', '', '1.81', '1.67', '']
# ['Dy', '2', 'VI', '', '1.21', '1.07', '']
# ['Er', '3', 'VI', '', '1.03', '0.89', 'R']
# ['Eu', '2', 'VI', '', '1.31', '1.17', '']
# ['Fr', '1', 'VI', '', '1.94', '1.8', 'A']
# ['Gd', '3', 'VI', '', '1.078', '0.938', 'R']
# ['Ge', '2', 'VI', '', '0.87', '0.73', 'A']
# ['Ho', '3', 'VI', '', '1.041', '0.901', 'R']
# ['I', '-1', 'VI', '', '2.06', '2.2', 'A']
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Step 1: Send an HTTP request and get HTML content
url = "http://abulafia.mt.ic.ac.uk/shannon/radius.php"
response = requests.get(url)
html_content = response.content

# Step 2: Use BeautifulSoup to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Step 3: Locate the table element and extract data with handling merged cells
table = soup.find('table')  # You may need to adjust this based on the actual HTML structure

if table:
    # Initialize variables to track merged column values
    previous_value = None

    # Iterate through rows
    for row in table.find_all('tr'):
        # Iterate through columns in each row
        columns = row.find_all(['td', 'th'])
        row_data = [column.text.strip() for column in columns]

        # Handle merged cells by repeating the previous value
        if len(row_data) >= 2:
            if row_data[1] != '':
                # Update the previous value if the current cell is not empty
                previous_value = row_data[1]
            else:
                # Repeat the previous value for the merged cell
                row_data[1] = previous_value

        # Process or print the data as needed
        print(row_data)
else:
    print("Table not found on the web page.")
# Out:
# ['', 'Radii for All Species']
# ['Ion', 'Charge', 'Coordination', 'Spin State', 'Crystal Radius', 'Ionic Radius', 'Key*']
# ['Ac', '3', 'VI', '', '1.26', '1.12', 'R']
# ['Ag', '1', 'II', '', '0.81', '0.67', '']
# ['IV', '1', '1.14', '1', 'C']
# ['IVSQ', '1', '1.16', '1.02', '']
# ['V', '1', '1.23', '1.09', 'C']
# ['VI', '1', '1.29', '1.15', 'C']
# ['VII', '1', '1.36', '1.22', '']
# ['VIII', '1', '1.42', '1.28', '']
# ['2', 'IVSQ', '', '0.93', '0.79', '']
# ['VI', 'IVSQ', '1.08', '0.94', '']
# ['3', 'IVSQ', '', '0.81', '0.67', '']
# ['VI', 'IVSQ', '0.89', '0.75', 'R']
# ['Al', '3', 'IV', '', '0.53', '0.39', '*']
# ['V', '3', '0.62', '0.48', '']
# ['VI', '3', '0.675', '0.535', 'R*']
# ['Am', '2', 'VII', '', '1.35', '1.21', '']
# ['VIII', '2', '1.4', '1.26', '']
# ['IX', '2', '1.45', '1.31', '']
# ['3', 'VI', '', '1.115', '0.975', 'R']
# ['VIII', 'VI', '1.23', '1.09', '']
# ['4', 'VI', '', '0.99', '0.85', 'R']
# ['VIII', 'VI', '1.09', '0.95', '']
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Step 1: Send an HTTP request and get HTML content
url = "http://abulafia.mt.ic.ac.uk/shannon/radius.php"
response = requests.get(url)
html_content = response.content

# Step 2: Use BeautifulSoup to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Step 3: Locate the table element and extract data with handling merged cells
table = soup.find('table')  # You may need to adjust this based on the actual HTML structure

if table:
    # Initialize variables to track merged column values
    previous_value = None
    previous_value1 = None
    previous_value2 = None

    # Iterate through rows
    for row in table.find_all('tr'):
        # Iterate through columns in each row
        columns = row.find_all(['td', 'th'])
        row_data = [column.text.strip() for column in columns]

        # Handle merged cells by repeating the previous value
        #if len(row_data) >=5:
        #    if len(row_data) ==6:
         #       # Update the previous value if the current cell is not empty
         #       previous_value = row_data[1]
         #   else:
                # Repeat the previous value for the merged cell
                #row_data[1] = previous_value
          #      row_data.insert(0, previous_value)

        if len(row_data) ==7:
          previous_value = row_data[0]
        if len(row_data)==6:
          previous_value1 = row_data[0]
          row_data.insert(0, previous_value)
        if len(row_data)==5:
          row_data.insert(0, previous_value1)
          row_data.insert(0, previous_value)
          #previous_value = row_data[0]
        if len(row_data) == 7 and row_data[2] == 'VI':
        #else:
          #row_data.insert(0, previous_value)
                # Repeat the previous value for the merged cell
                #row_data[1] = previous_value

            #if len(row_data) ==6:
                # Update the previous value if the current cell is not empty
            #    previous_value = row_data[1]
            #else:
                # Repeat the previous value for the merged cell
                #row_data[1] = previous_value
              #  row_data.insert(0, previous_value)

        # Process or print the data as needed
          print(row_data)
else:
    print("Table not found on the web page.")
# Out:
# ['Ac', '3', 'VI', '', '1.26', '1.12', 'R']
# ['Ag', None, 'VI', '', '1.29', '1.15', 'C']
# ['Ag', '2', 'VI', '', '1.08', '0.94', '']
# ['Ag', '3', 'VI', '', '0.89', '0.75', 'R']
# ['Al', '3', 'VI', '', '0.675', '0.535', 'R*']
# ['Am', '3', 'VI', '', '1.115', '0.975', 'R']
# ['Am', '4', 'VI', '', '0.99', '0.85', 'R']
# ['As', '3', 'VI', '', '0.72', '0.58', 'A']
# ['As', '5', 'VI', '', '0.6', '0.46', 'C*']
# ['At', '7', 'VI', '', '0.76', '0.62', 'A']
# ['Au', '1', 'VI', '', '1.51', '1.37', 'A']
# ['Au', '3', 'VI', '', '0.99', '0.85', 'A']
# ['Au', '5', 'VI', '', '0.71', '0.57', '']
# ['B', '5', 'VI', '', '0.41', '0.27', 'C']
# ['Ba', '2', 'VI', '', '1.49', '1.35', '']
# ['Be', '5', 'VI', '', '0.59', '0.45', 'C']
# ['Bi', '5', 'VI', '', '1.17', '1.03', 'R*']
# ['Bi', '5', 'VI', '', '0.9', '0.76', 'E']
# ['Bk', '3', 'VI', '', '1.1', '0.96', 'R']
# ['Bk', '4', 'VI', '', '0.97', '0.83', 'R']
# ['Br', '-1', 'VI', '', '1.82', '1.96', 'P']
# ['Br', '7', 'VI', '', '0.53', '0.39', 'A']
# ...
